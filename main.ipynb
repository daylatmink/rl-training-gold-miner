# %%
import torch
import pickle

# %%
ck = torch.load('C:\\Users\\User\\Documents\\code\\rl-training-gold-miner\\checkpoints\\checkpoint_step5000.pt')

# %%
ck.keys()
# Out:
# dict_keys(['agent_state_dict', 'target_agent_state_dict', 'optimizer_state_dict', 'epsilon', 'total_steps', 'episode_rewards', 'episode_lengths', 'replay_buffer'])

# %%
replay_buffer = ck['replay_buffer']

# %%
replay_buffer[0][-1]
# Out:
# 8

# %%
cnt = [0] * 51
for env_feats, item_feats, masks, actions, rewards, seq_len in replay_buffer:
    for i in range(seq_len):
        cnt[actions[i]] += 1
print(cnt)
# Out:
# [657, 582, 555, 701, 753, 967, 797, 690, 990, 903, 702, 1600, 728, 1240, 1540, 758, 982, 883, 810, 634, 1062, 937, 1069, 1140, 806, 737, 1271, 842, 784, 1043, 722, 884, 1058, 858, 1454, 1334, 1241, 1478, 1362, 1059, 1104, 1107, 673, 885, 1082, 779, 759, 886, 740, 815, 5000]

# %%
path = r"C:\Users\User\Documents\code\rl-training-gold-miner\warmup_buffer_rnn_5k_new.pkl"
pot = pickle.load(open(path, 'rb'))

# %%
cnt = [0] * 51
for env_feats, item_feats, masks, actions, rewards, seq_len in pot:
    for i in range(seq_len):
        cnt[actions[i]] += 1
print(cnt)
# Out:
# [958, 952, 970, 974, 1017, 969, 943, 1030, 915, 904, 926, 935, 972, 1038, 961, 968, 989, 879, 956, 958, 961, 943, 926, 956, 962, 938, 937, 958, 929, 902, 912, 952, 961, 958, 952, 939, 916, 900, 961, 957, 959, 911, 942, 951, 987, 982, 935, 960, 927, 1009, 5000]

# %%
cnt[38]
# Out:
# 961
