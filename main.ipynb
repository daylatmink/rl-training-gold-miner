# %%
import torch
import pickle
from agent.Qtention.Qtention import Qtention

# %%
ck = pickle.load(open('buffers/warmup_buffer_qtention.pkl', 'rb'))

# %%
len(ck)
# Out:
# 20000

# %%
type_ids, item_feats, mov_idx, mov_feats, length, action, reward, new_type_ids, new_item_feats, new_mov_idx, new_mov_feats, new_length, done = ck[0]

# %%
# Mask: True cho padding positions, False cho real tokens
# type_ids có shape [31] (1 ENV + 30 items), length = số tokens thực tế
mask = (torch.arange(31) >= length)   # shape [31], dtype=bool
print(f"mask.shape: {mask.shape}, dtype: {mask.dtype}")
print(f"Real tokens: {(~mask).sum().item()}, Padded: {mask.sum().item()}")
mask
# Out:
# mask.shape: torch.Size([31]), dtype: torch.bool
# Real tokens: 14, Padded: 17
# tensor([False, False, False, False, False, False, False, False, False, False,
#         False, False, False, False,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True])

# %%
agent = Qtention(d_model = 32, d_ff = 48, nhead = 8, n_layers = 6)

# %%
total_params = sum(p.numel() for p in agent.parameters())
print(f"Total number of parameters: {total_params}")
# Out:
# Total number of parameters: 48961

# %%
agent(type_ids.unsqueeze(0), item_feats.unsqueeze(0), mov_idx.unsqueeze(0), mov_feats.unsqueeze(0), mask.unsqueeze(0))
# Out:
# tensor([[-4.7971e-05, -4.7579e-05, -5.4515e-05, -5.4299e-05, -5.7088e-05,
#          -5.3150e-05, -5.6309e-05, -5.4400e-05, -6.0479e-05, -5.6254e-05,
#          -5.4689e-05, -6.2990e-05, -4.9479e-05, -4.5281e-05, -5.6971e-05,
#          -4.9825e-05, -5.3758e-05, -5.6384e-05, -5.6548e-05, -4.9353e-05,
#          -4.9702e-05, -4.9941e-05, -4.8356e-05, -5.4709e-05, -5.5432e-05,
#          -5.8576e-05, -4.9015e-05, -5.5833e-05, -5.4787e-05, -5.1556e-05,
#          -5.8921e-05, -4.9062e-05, -5.0388e-05, -6.2955e-05, -5.7168e-05,
#          -5.4842e-05, -5.2092e-05, -5.5372e-05, -5.6499e-05, -5.8014e-05,
#          -5.6921e-05, -5.7249e-05, -5.2071e-05, -5.6615e-05, -4.9690e-05,
#          -6.2316e-05, -5.9884e-05, -5.5661e-05, -6.5649e-05, -5.3851e-05]],
#        grad_fn=<SqueezeBackward1>)

# %%
agent(type_ids, item_feats, mov_idx, mov_feats, length)
